# %% [markdown]
# # Type  Of Python Operators:
# # 8 - Identity  Operators

# %%
# is : returns True if both variables refer to the same object in memory.
list_1 = [1, 2, 3]
list_2 = list_1
print(list_1 is list_2)   # True (same object in memory)

# %%
# is not : returns True if variables refer to different objects in memory
list_1 = [1, 2, 3]
list_2 = [1, 2, 3]
print(list_1 is not blist_2)   # True (different memory locations)
